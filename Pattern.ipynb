# %%
n=int(input())
i=1
while i<=n:
    j=1
    while j<=n:
        print(n,end=(''))
        j=j+1
    print()
    i=i+1
# Out:
# 4
# 4444
# 4444
# 4444
# 4444

# %%
n=int(input())
i=1
while i<=n:
    j=0
    while j<n:
        j=j+1
        print(j,end=(''))
    print()
    i=i+1
# Out:
# 4
# 1234
# 1234
# 1234
# 1234

# %%
n=int(input())
i=1
while i<=n:
    j=1
    while j<=n:
        print(i,end=(''))
        j=j+1
    print()
    i=i+1
# Out:
# 5
# 11111
# 22222
# 33333
# 44444
# 55555

# %%
n=int(input())
i=1
while i<=n:
    j=1
    while j<=n:
        print((n-j+1),end=(''))
        j=j+1
    print()
    i=i+1
# Out:
# 4
# 4321
# 4321
# 4321
# 4321

# %%
n=int(input())
i=1
while i<=n:
    j=1
    p=i
    while j<=i:
        print(p,end=(""))
        j=j+1
        p=p+1
    print()
    i=i+1
# Out:
# 4
# 1
# 23
# 345
# 4567

# %%
n=int(input())
i=1
p=1
while(i<n):
    j=1
    while (j<i):
        print(p,end=(''))
        p=p+1
        j=j+1
    print()
    i+1
# Out:
# 4
# KeyboardInterrupt

# %%
n=int(input())
i=1
while i<=n:
    j=1
    while j<=n:
        print((n-j+1),end=(''))
        j=j+1
    print()
    i=i+1
